# %%
# Import dependencies
from citipy import citipy
import pandas as pd
import numpy as np
import json 
import requests
import timeit

from datetime import datetime
from config import weather_api_key

# %%
# Create a new set of 2,000 random latitudes and longitudes
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)

# Unpack lat_lngs zip object into a list. This way, we only need to create a set of random latitudes and longitudes once. 
lat_lngs = zip(lats, lngs)
lat_lngs

# One can only unzip a zipped tuple once before it is removed from the computer's memory. 
# Make sure to unzip the latitudes and longitudes into the coordinates list before moving on.

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)
print (coordinates)
# Out:
# [(83.71070721075125, 76.50208740347733), (-7.358162150375605, 96.57159689249193), (-39.780985981656855, 20.705698163197525), (60.1192914282567, -104.12642166261273), (58.84420894042603, -49.46901215212992), (61.62976397218091, 150.4636827509563), (44.58960771212267, -53.51347212459851), (7.653106511961951, 84.94324037715131), (62.293309342462834, -100.87340280209249), (23.58717643481232, 23.050250715521997), (-50.523375161142006, -132.3593183188798), (58.55022436134598, 48.92457937615802), (18.397711949355312, 128.48580007793305), (-35.94701908592587, -3.9605774435914327), (54.792459650954214, 47.39391227106785), (-88.0504688000679, -24.807558959980383), (59.02148496545476, -146.34455898984643), (35.97822671823509, -154.03356692735204), (45.38776145040427, 71.02203015112823), (-36.015093244384744, -79.59575540979063), (-24.58658357909978, 162.9759842183995), (-52.52592489951166, 170.390618796441), (-1.8527844016076358, 159.43159838522593), (-54.54266024739456, -162.31376123810574), (65.96592352495466, -149.16171433340966), (-32.8467604387305, 158.10140549486744), (-35.81709488253358, 35.65534745176373), (-2.755064680597428, 74.09261925483224), (80.21937568117752, 29.252550358892762), (60.836380880344365, 88.88646396642508), (-15.590824632227765, 56.01411214435825), (76.74140206674642, -144.351800125598), (13.741166427340204, 62.500215357597654), (70.20998917405413, 177.06141800933318), (28.30710606164017, 114.62768050930225), (70.28125191085829, 38.58213779910983), (27.40161470304008, 15.979691891142267), (24.5218739621194, -19.76818647819988), (4.392867489997229, 31.617177116763997), (-32.85142597596053, -135.4698529485268), (-3.591335120391946, -48.803774649012354), (-89.68059732024965, -60.45733542040904), (-28.14037197436619, 130.33778415093252), (63.241682019381216, 131.60311171389088), (10.50617628481423, 144.2147036761528), (-75.08348537141102, 25.53338225891474), (-37.51534264319095, -161.37576878363083), (19.54702300670658, -117.54414953590053), (-84.31911883277833, -165.91932397465413), (-16.766918234742093, -56.14487860205678), (-10.712027946696153, 141.89025356827204), (-50.18580702858493, 138.3810969683737), (-32.55222816591617, 42.84426676772716), (-28.869771953355716, 11.65587229511155), (44.761646775994706, 126.16782534164122), (52.590102788266194, 29.01624050142391), (15.618455463895913, 162.7838312430431), (80.635287941564, 46.03758091967012), (70.74690044971933, 63.969316238130375), (-61.54965027494917, -29.54312640933844), (-64.64865803627337, 94.10788412187833), (-37.989038383104365, 177.86726724539267), (59.565745872959894, -32.024736140084826), (5.43867114614909, -106.64296017212996), (83.39848934838636, 132.29910991576605), (-6.93871393513318, -130.548438078548), (8.784438959563616, -53.86925858317977), (-56.91615565525316, -177.57022568749335), (-28.063806064804318, 128.9143563756839), (-81.6843407695976, -133.07588253866285), (-20.46885673556892, 103.67148289487409), (-39.625477162233324, 168.11928113518172), (20.754508120456364, 50.87115996542224), (52.43771049122387, 66.2661699110609), (-46.65979419025518, -124.97731798809022), (-17.080109392222965, -93.52287807248365), (-70.32301548480463, 79.63873434535282), (72.1481475165464, 133.36799856640113), (-37.171519982187995, 10.503980242637482), (-35.83597558449816, -159.54009242553747), (-67.93074867302536, 52.82171916951202), (-61.764094372112076, -8.736567744814465), (-24.83233426377477, 125.54733634599569), (4.8671427319343366, -115.49478445827569), (-45.06288485663935, 149.4190449674711), (27.64440417725409, -68.9811589177505), (11.595959063853812, -40.741398704110054), (-26.58528478492223, -165.18152606001675), (-77.75142044326759, -126.2671195985118), (1.4512742175064375, 150.42028045382858), (36.312669824788316, -92.16600224572876), (-66.72806604002645, 96.04845144071669), (75.63350552702465, 139.81860385100737), (-81.38634799673963, -19.98521894668849), (-29.89042349088239, -26.205305107608098), (-70.73296000258453, -138.37921154014037), (11.17 ...

# %%
# Get the nearest city using the citipy module
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 777

# %%
# Out:
# []

# %%
# Perform an API call with the OpenWeatherMap
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Retrieve the following information from the API call:
# Latitude and longitude
# Maximum temperature
# Percent humidity
# Percent cloudiness
# Wind speed
# Weather description (for example, clouds, fog, light rain, clear sky)

# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    
    # Add 1 to the record count.
    record_count += 1
    
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_country = city_weather["sys"]["country"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        description = city_weather['weather'][0]['description']
        
        # Convert the date to ISO
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        
        # Append the city information to the city_data list
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description":description })

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | dikson
# Processing Record 2 of Set 1 | bengkulu
# Processing Record 3 of Set 1 | bredasdorp
# Processing Record 4 of Set 1 | la ronge
# Processing Record 5 of Set 1 | paamiut
# Processing Record 6 of Set 1 | sinegorye
# Processing Record 7 of Set 1 | bay roberts
# Processing Record 8 of Set 1 | kalmunai
# Processing Record 9 of Set 1 | thompson
# Processing Record 10 of Set 1 | jalu
# Processing Record 11 of Set 1 | rikitea
# Processing Record 12 of Set 1 | orichi
# Processing Record 13 of Set 1 | pandan
# Processing Record 14 of Set 1 | jamestown
# Processing Record 15 of Set 1 | shemursha
# Processing Record 16 of Set 1 | ushuaia
# Processing Record 17 of Set 1 | palmer
# Processing Record 18 of Set 1 | kapaa
# Processing Record 19 of Set 1 | zhanatas
# City not found. Skipping...
# Processing Record 20 of Set 1 | lebu
# Processing Record 21 of Set 1 | poya
# Processing Record 22 of Set 1 | bluff
# Processing Record 23 of Set 1 | kieta
# Processing Record 24 of Set 1 | avarua
# Processing Record 25 of Set 1 | college
# Processing Record 26 of Set 1 | port macquarie
# Processing Record 27 of Set 1 | margate
# Processing Record 28 of Set 1 | hithadhoo
# Processing Record 29 of Set 1 | mehamn
# Processing Record 30 of Set 1 | teguldet
# Processing Record 31 of Set 1 | cap malheureux
# Processing Record 32 of Set 1 | fairbanks
# Processing Record 33 of Set 1 | salalah
# Processing Record 34 of Set 1 | leningradskiy
# Processing Record 35 of Set 1 | fenyi
# Processing Record 36 of Set 1 | ostrovnoy
# Processing Record 37 of Set 1 | sabha
# Processing Record 38 of Set 1 | nouadhibou
# Processing Record 39 of Set 1 | juba
# Processing Record 40 of Set 1 | tucurui
# Processing Record 41 of Set 1 | yulara
# Processing Record 42 of Set 1 | borogontsy
# Processing Record 43 of Set 1 | airai
# Processing Record 44 of Set 1 | constitucion
# Processing Record 45 of Set 1 | mataura
# Processing Record 46 of Set 1 | barao de melgaco
# Processing Record 47 of Set 1 | daru
# Processing Record 48 of Set 1 | new norfolk
# Processing Record 49 of Set 1 | beloha
# Processing Record 50 of Set 1 | luderitz
# Processing Record 1 of Set 2 | yushu
# Processing Record 2 of Set 2 | mazyr
# Processing Record 3 of Set 2 | butaritari
# Processing Record 4 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 5 of Set 2 | amderma
# City not found. Skipping...
# Processing Record 6 of Set 2 | mar del plata
# Processing Record 7 of Set 2 | busselton
# Processing Record 8 of Set 2 | te karaka
# Processing Record 9 of Set 2 | tasiilaq
# Processing Record 10 of Set 2 | ixtapa
# Processing Record 11 of Set 2 | tiksi
# Processing Record 12 of Set 2 | atuona
# Processing Record 13 of Set 2 | mana
# Processing Record 14 of Set 2 | vaini
# Processing Record 15 of Set 2 | carnarvon
# Processing Record 16 of Set 2 | westport
# Processing Record 17 of Set 2 | abu samrah
# Processing Record 18 of Set 2 | esil
# Processing Record 19 of Set 2 | san cristobal
# Processing Record 20 of Set 2 | nizhneyansk
# City not found. Skipping...
# Processing Record 21 of Set 2 | saldanha
# Processing Record 22 of Set 2 | east london
# Processing Record 23 of Set 2 | cape town
# Processing Record 24 of Set 2 | san patricio
# Processing Record 25 of Set 2 | hobart
# Processing Record 26 of Set 2 | hamilton
# Processing Record 27 of Set 2 | cayenne
# Processing Record 28 of Set 2 | kavieng
# Processing Record 29 of Set 2 | mountain home
# Processing Record 30 of Set 2 | sao joao da barra
# Processing Record 31 of Set 2 | oussouye
# Processing Record 32 of Set 2 | grand gaube
# Processing Record 33 of Set 2 | lincoln
# Processing Record 34 of Set 2 | ambon
# Processing Record 35 of Set 2 | namibe
# Processing Record 36 of Set 2 | brenham
# Processing Record 37 of Set 2 | betsiamites
# Processing Record 38 of Set 2 | bambous virieux
# Processing Record 39 of Set 2 | jamalpur
# Processing Record 40 of Set 2 | angoram
# Processing Record 41 of Set 2 | inirida
# Processing Record 42 of Set 2 | roma
# Processing Record 43 of Set 2 | khatanga
# Processing Record 44 of Set 2 | kuche
# City not found. Skipping...
# Processing Record 45 of Set 2 | san jeronimo
# Processing Record 46 of Set 2 | vera cruz
# Processing Record 47 of Set 2 | matagami
# Processing Record 48 of Set 2 | bosaso
# Processing Record 49 of Set 2 | portland
# Processing Record 50 of Set 2 | linfen
# Processing Record 1 of Set 3 | qaanaaq
# Processing Record 2 of Set 3 | beipiao
# Processing Record 3 of Set 3 | barrow
# Processing Record 4 of Set 3 | hunza
# City not found. Skipping...
# Processing Record 5 of Set 3 | pichayevo
# Processing Record 6 of Set 3 | beringovskiy
# Processing Record 7 of Set 3 | katsuura
# Processing Record 8 of Set 3 | albany
# Processing Record 9 of Set 3 | alofi
# Processing Record 10 of Set 3 | athabasca
# Processing Record 11 of Set 3 | deputatskiy
# Processing Record 12 of Set 3 | chaman
# Processing Record 13 of Set 3 | point pedro
# Processing Record 14 of Set 3 | hit
# Processing Record 15 of Set 3 | labuhan
# Processing Record 16 of Set 3 | dhanwar
# Processing Record 17 of Set 3 | touros
# Processing Record 18 of Set 3 | dukat
# Processing Record 19 of Set 3 | codrington
# Processing Record 20 of Set 3 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 21 of Set 3 | coahuayana
# Processing Record 22 of Set 3 | durango
# Processing Record 23 of Set 3 | hasaki
# Processing Record 24 of Set 3 | severo-kurilsk
# Processing Record 25 of Set 3 | trinidad
# Processing Record 26 of Set 3 | sibanicu
# Processing Record 27 of Set 3 | port alfred
# Processing Record 28 of Set 3 | diamantino
# Processing Record 29 of Set 3 | medowie
# Processing Record 30 of Set 3 | lompoc
# Processing Record 31 of Set 3 | ambulu
# Processing Record 32 of Set 3 | hilo
# Processing Record 33 of Set 3 | sentyabrskiy
# City not found. Skipping...
# Processing Record 34 of Set 3 | umzimvubu
# City not found. Skipping...
# Processing Record 35 of Set 3 | gushikawa
# Processing Record 36 of Set 3 | mys shmidta
# City not found. Skipping...
# Processing Record 37 of Set 3 | matay
# Processing Record 38 of Set 3 | maldonado
# Processing Record 39 of Set 3 | taolanaro
# City not found. Skipping...
# Processing Record 40 of Set 3 | fevralsk
# City not found. Skipping...
# Processing Record 41 of Set 3 | timra
# Processing Record 42 of Set 3 | chifeng
# Processing Record 43 of Set 3 | garissa
# Processing Record 44 of Set 3 | kalaleh
# Processing Record 45 of Set 3 | okhotsk
# Processing Record 46 of Set 3 | bubaque
# Processing Record 47 of Set 3 | nikolskoye
# Processing Record 48 of Set 3 | itoman
# Processing Record 49 of Set 3 | bathsheba
# Processing Record 50 of Set 3 | berlevag
# Processing Record 1 of Set 4 | prainha
# Processing Record 2 of Set 4 | cooma
# Processing Record 3 of Set 4 | arukutti
# Processing Record 4 of Set 4 | fortuna
# Processing Record 5 of Set 4 | pevek
# Processing Record 6 of Set 4 | calama
# Processing Record 7 of Set 4 | temple
# Processing Record 8 of Set 4 | faanui
# Processing Record 9 of Set 4 | hofn
# Processing Record 10 of Set 4 | iskateley
# Processing Record 11 of Set 4 | bethel
# Processing Record 12 of Set 4 | tuktoyaktuk
# Processing Record 13 of Set 4 | camacha
# Processing Record 14 of Set 4 | goure
# Processing Record 15 of Set 4 | auki
# Processing Record 16 of Set 4 | sisimiut
# Processing Record 17 of Set 4 | lingao
# Processing Record 18 of Set 4 | novosemeykino
# Processing Record 19 of Set 4 | taltal
# Processing Record 20 of Set 4 | vaitupu
# City not found. Skipping...
# Processing Record 21 of Set 4 | koboldo
# City not found. Skipping...
# Processing Record 22 of Set 4 | pascagoula
# Processing Record 23 of Set 4 | punta arenas
# Processing Record 24 of Set 4 | cherskiy
# Processing Record 25 of Set 4 | mezhdurechensk
# Processing Record 26 of Set 4 | castro
# Processing Record 27 of Set 4 | lavrentiya
# Processing Record 28 of Set 4 | baruun-urt
# Processing Record 29 of Set 4 | caravelas
# Processing Record 30 of Set 4 | lata
# Processing Record 31 of Set 4 | marienburg
# Processing Record 32 of Set 4 | ransang
# Processing Record 33 of Set 4 | chapais
# Processing Record 34 of Set 4 | smithers
# Processing Record 35 of Set 4 | buala
# Processing Record 36 of Set 4 | guiratinga
# Processing Record 37 of Set 4 | chapala
# Processing Record 38 of Set 4 | marcona
# City not found. Skipping...
# Processing Record 39 of Set 4 | independence
# Processing Record 40 of Set 4 | meiganga
# Processing Record 41 of Set 4 | hermanus
# Processing Record 42 of Set 4 | yenagoa
# Processing Record 43 of Set 4 | kaseda
# Processing Record 44 of Set 4 | iqaluit
# Processing Record 45 of Set 4 | itapirapua
# Processing Record 46 of Set 4 | buncrana
# Processing Record 47 of Set 4 | monte santo
# Processing Record 48 of Set 4 | isangel
# Processing Record 49 of Set 4 | werota
# Processing Record 50 of Set 4 | labutta
# City not found. Skipping...
# Processing Record 1 of Set 5 | cochrane
# Processing Record 2 of Set 5 | pangkalanbuun
# Processing Record 3 of Set 5 | kichera
# Processing Record 4 of Set 5 | vardo
# Processing Record 5 of Set 5 | hay river
# Processing Record 6 of Set 5 | bilibino
# Processing Record 7 of Set 5 | norman wells
# Processing Record 8 of Set 5 | port lincoln
# Processing Record 9 of Set 5 | laguna
# Processing Record 10 of Set 5 | yerbogachen
# Processing Record 11 of Set 5 | tsihombe
# City not found. Skipping...
# Processing Record 12 of Set 5 | barra patuca
# Processing Record 13 of Set 5 | waipawa
# Processing Record 14 of Set 5 | yumen
# Processing Record 15 of Set 5 | chuy
# Processing Record 16 of Set 5 | kodiak
# Processing Record 17 of Set 5 | nuevo progreso
# Processing Record 18 of Set 5 | changji
# Processing Record 19 of Set 5 | abu dhabi
# Processing Record 20 of Set 5 | nishihara
# Processing Record 21 of Set 5 | barstow
# Processing Record 22 of Set 5 | arraial do cabo
# Processing Record 23 of Set 5 | buluang
# Processing Record 24 of Set 5 | esperance
# Processing Record 25 of Set 5 | stuttgart
# Processing Record 26 of Set 5 | yaan
# Processing Record 27 of Set 5 | filingue
# Processing Record 28 of Set 5 | hami
# Processing Record 29 of Set 5 | kondoa
# Processing Record 30 of Set 5 | dingle
# Processing Record 31 of Set 5 | port hardy
# Processing Record 32 of Set 5 | macomer
# Processing Record 33 of Set 5 | yima
# Processing Record 34 of Set 5 | turukhansk
# Processing Record 35 of Set 5 | kargil
# Processing Record 36 of Set 5 | cabo san lucas
# Processing Record 37 of Set 5 | dudinka
# Processing Record 38 of Set 5 | la plata
# Processing Record 39 of Set 5 | ribeira grande
# Processing Record 40 of Set 5 | tarko-sale
# Processing Record 41 of Set 5 | farmington
# Processing Record 42 of Set 5 | gorno-chuyskiy
# City not found. Skipping...
# Processing Record 43 of Set 5 | attawapiskat
# City not found. Skipping...
# Processing Record 44 of Set 5 | barentsburg
# City not found. Skipping...
# Processing Record 45 of Set 5 | ponta do sol
# Processing Record 46 of Set 5 | upernavik
# Processing Record 47 of Set 5 | shetpe
# Processing Record 48 of Set 5 | pemba
# Processing Record 49 of Set 5 | utiroa
# City not found. Skipping...
# Processing Record 50 of Set 5 | port elizabeth
# Processing Record 1 of Set 6 | komatipoort
# Processing Record 2 of Set 6 | lerwick
# Processing Record 3 of Set 6 | yellowknife
# Processing Record 4 of Set 6 | horsham
# Processing Record 5 of Set 6 | fukue
# Processing Record 6 of Set 6 | adrar
# Processing Record 7 of Set 6 | salinas
# Processing Record 8 of Set 6 | pangnirtung
# Processing Record 9 of Set 6 | shelburne
# Processing Record 10 of Set 6 | satitoa
# City not found. Skipping...
# Processing Record 11 of Set 6 | belle glade
# Processing Record 12 of Set 6 | north bend
# Processing Record 13 of Set 6 | mahibadhoo
# Processing Record 14 of Set 6 | tabiauea
# City not found. Skipping...
# Processing Record 15 of Set 6 | kupang
# Processing Record 16 of Set 6 | tocopilla
# Processing Record 17 of Set 6 | coquimbo
# Processing Record 18 of Set 6 | praia
# Processing Record 19 of Set 6 | nyrob
# Processing Record 20 of Set 6 | mnogovershinnyy
# Processing Record 21 of Set 6 | talnakh
# Processing Record 22 of Set 6 | khandyga
# Processing Record 23 of Set 6 | dunedin
# Processing Record 24 of Set 6 | alice springs
# Processing Record 25 of Set 6 | hovd
# Processing Record 26 of Set 6 | inhambane
# Processing Record 27 of Set 6 | saint-philippe
# Processing Record 28 of Set 6 | warqla
# City not found. Skipping...
# Processing Record 29 of Set 6 | nanortalik
# Processing Record 30 of Set 6 | toamasina
# Processing Record 31 of Set 6 | mikhaylovskoye
# Processing Record 32 of Set 6 | tarakan
# Processing Record 33 of Set 6 | haines junction
# Processing Record 34 of Set 6 | acapulco
# Processing Record 35 of Set 6 | salvador
# Processing Record 36 of Set 6 | limbang
# Processing Record 37 of Set 6 | chokurdakh
# Processing Record 38 of Set 6 | tomatlan
# Processing Record 39 of Set 6 | tromso
# Processing Record 40 of Set 6 | bindura
# Processing Record 41 of Set 6 | marabba
# Processing Record 42 of Set 6 | mahebourg
# Processing Record 43 of Set 6 | nome
# Processing Record 44 of Set 6 | beya
# Processing Record 45 of Set 6 | bafra
# Processing Record 46 of Set 6 | ponta delgada
# Processing Record 47 of Set 6 | bonnyville
# Processing Record 48 of Set 6 | kaitangata
# Processing Record 49 of Set 6 | kyaikto
# Processing Record 50 of Set 6 | port-cartier
# Processing Record 1 of Set 7 | tura
# Processing Record 2 of Set 7 | plouzane
# Processing Record 3 of Set 7 | cibitoke
# Processing Record 4 of Set 7 | sarai
# Processing Record 5 of Set 7 | kahului
# Processing Record 6 of Set 7 | bellefontaine
# Processing Record 7 of Set 7 | lorengau
# Processing Record 8 of Set 7 | puerto ayora
# Processing Record 9 of Set 7 | hede
# Processing Record 10 of Set 7 | guerrero negro
# Processing Record 11 of Set 7 | hirara
# Processing Record 12 of Set 7 | aasiaat
# Processing Record 13 of Set 7 | muli
# Processing Record 14 of Set 7 | champerico
# Processing Record 15 of Set 7 | sao filipe
# Processing Record 16 of Set 7 | saint-augustin
# Processing Record 17 of Set 7 | bunbury
# Processing Record 18 of Set 7 | saint george
# Processing Record 19 of Set 7 | tilichiki
# Processing Record 20 of Set 7 | cozumel
# Processing Record 21 of Set 7 | homer
# Processing Record 22 of Set 7 | saskylakh
# Processing Record 23 of Set 7 | ituni
# City not found. Skipping...
# Processing Record 24 of Set 7 | pisco
# Processing Record 25 of Set 7 | mayskiy
# Processing Record 26 of Set 7 | flinders
# Processing Record 27 of Set 7 | kati
# Processing Record 28 of Set 7 | nzerekore
# Processing Record 29 of Set 7 | artyk
# City not found. Skipping...
# Processing Record 30 of Set 7 | nara
# Processing Record 31 of Set 7 | cervo
# Processing Record 32 of Set 7 | rawson
# Processing Record 33 of Set 7 | savannah bight
# Processing Record 34 of Set 7 | kiama
# Processing Record 35 of Set 7 | vestmanna
# Processing Record 36 of Set 7 | pokosnoye
# Processing Record 37 of Set 7 | ust-kut
# Processing Record 38 of Set 7 | samusu
# City not found. Skipping...
# Processing Record 39 of Set 7 | jiazi
# Processing Record 40 of Set 7 | port-gentil
# Processing Record 41 of Set 7 | atar
# Processing Record 42 of Set 7 | baft
# Processing Record 43 of Set 7 | xianyang
# Processing Record 44 of Set 7 | rio claro
# Processing Record 45 of Set 7 | lixourion
# Processing Record 46 of Set 7 | gravdal
# Processing Record 47 of Set 7 | torbay
# Processing Record 48 of Set 7 | cherkasskoye
# Processing Record 49 of Set 7 | ilulissat
# Processing Record 50 of Set 7 | rocha
# Processing Record 1 of Set 8 | oga
# Processing Record 2 of Set 8 | itarema
# Processing Record 3 of Set 8 | pandan niog
# Processing Record 4 of Set 8 | urdzhar
# City not found. Skipping...
# Processing Record 5 of Set 8 | kemin
# Processing Record 6 of Set 8 | cockburn town
# Processing Record 7 of Set 8 | saint-leu
# Processing Record 8 of Set 8 | palabuhanratu
# City not found. Skipping...
# Processing Record 9 of Set 8 | sorvag
# City not found. Skipping...
# Processing Record 10 of Set 8 | sogdiondon
# City not found. Skipping...
# Processing Record 11 of Set 8 | dzhebariki-khaya
# Processing Record 12 of Set 8 | tungor
# Processing Record 13 of Set 8 | pahrump
# Processing Record 14 of Set 8 | urubicha
# Processing Record 15 of Set 8 | doha
# Processing Record 16 of Set 8 | rawannawi
# City not found. Skipping...
# Processing Record 17 of Set 8 | luanda
# Processing Record 18 of Set 8 | pilar
# Processing Record 19 of Set 8 | ca mau
# Processing Record 20 of Set 8 | novo aripuana
# Processing Record 21 of Set 8 | songjianghe
# Processing Record 22 of Set 8 | poum
# Processing Record 23 of Set 8 | wrexham
# Processing Record 24 of Set 8 | oleksandrivka
# Processing Record 25 of Set 8 | souillac
# Processing Record 26 of Set 8 | sitka
# Processing Record 27 of Set 8 | tuggurt
# City not found. Skipping...
# Processing Record 28 of Set 8 | belaya kholunitsa
# Processing Record 29 of Set 8 | port keats
# Processing Record 30 of Set 8 | dicabisagan
# Processing Record 31 of Set 8 | krasnoselkup
# Processing Record 32 of Set 8 | ngunguru
# Processing Record 33 of Set 8 | saleaula
# City not found. Skipping...
# Processing Record 34 of Set 8 | calvinia
# Processing Record 35 of Set 8 | victor harbor
# Processing Record 36 of Set 8 | houma
# Processing Record 37 of Set 8 | bowen
# Processing Record 38 of Set 8 | victoria
# Processing Record 39 of Set 8 | kamenskoye
# City not found. Skipping...
# Processing Record 40 of Set 8 | newport
# Processing Record 41 of Set 8 | te anau
# Processing Record 42 of Set 8 | pitimbu
# Processing Record 43 of Set 8 | asau
# Processing Record 44 of Set 8 | sivaki
# Processing Record 45 of Set 8 | grindavik
# Processing Record 46 of Set 8 | walvis bay
# Processing Record 47 of Set 8 | bloomfield
# Processing Record 48 of Set 8 | lagoa
# Processing Record 49 of Set 8 | warmbad
# Processing Record 50 of Set 8 | batsfjord
# Processing Record 1 of Set 9 | aswan
# Processing Record 2 of Set 9 | jujuy
# City not found. Skipping...
# Processing Record 3 of Set 9 | nago
# Processing Record 4 of Set 9 | osorno
# Processing Record 5 of Set 9 | ouesso
# Processing Record 6 of Set 9 | tracy
# Processing Record 7 of Set 9 | faya
# Processing Record 8 of Set 9 | thinadhoo
# Processing Record 9 of Set 9 | grand river south east
# City not found. Skipping...
# Processing Record 10 of Set 9 | fort nelson
# Processing Record 11 of Set 9 | pangody
# Processing Record 12 of Set 9 | nyurba
# Processing Record 13 of Set 9 | srednekolymsk
# Processing Record 14 of Set 9 | imisli
# City not found. Skipping...
# Processing Record 15 of Set 9 | vao
# Processing Record 16 of Set 9 | abha
# Processing Record 17 of Set 9 | bolungarvik
# City not found. Skipping...
# Processing Record 18 of Set 9 | tumannyy
# City not found. Skipping...
# Processing Record 19 of Set 9 | carahue
# Processing Record 20 of Set 9 | otacilio costa
# Processing Record 21 of Set 9 | sandviken
# Processing Record 22 of Set 9 | omboue
# Processing Record 23 of Set 9 | vanimo
# Processing Record 24 of Set 9 | bintulu
# Processing Record 25 of Set 9 | monrovia
# Processing Record 26 of Set 9 | antofagasta
# Processing Record 27 of Set 9 | igarka
# Processing Record 28 of Set 9 | hobyo
# Processing Record 29 of Set 9 | belmonte
# Processing Record 30 of Set 9 | chiang klang
# Processing Record 31 of Set 9 | aklavik
# Processing Record 32 of Set 9 | tkvarcheli
# City not found. Skipping...
# Processing Record 33 of Set 9 | ouadda
# Processing Record 34 of Set 9 | necochea
# Processing Record 35 of Set 9 | gat
# Processing Record 36 of Set 9 | shahr-e babak
# Processing Record 37 of Set 9 | upington
# Processing Record 38 of Set 9 | saint-louis
# Processing Record 39 of Set 9 | sataua
# City not found. Skipping...
# Processing Record 40 of Set 9 | adamas
# Processing Record 41 of Set 9 | tuatapere
# Processing Record 42 of Set 9 | san andres
# Processing Record 43 of Set 9 | havelock
# Processing Record 44 of Set 9 | rio grande
# Processing Record 45 of Set 9 | hope
# Processing Record 46 of Set 9 | karaton
# Processing Record 47 of Set 9 | flin flon
# Processing Record 48 of Set 9 | araioses
# Processing Record 49 of Set 9 | bulungu
# Processing Record 50 of Set 9 | makakilo city
# Processing Record 1 of Set 10 | warrington
# Processing Record 2 of Set 10 | kharan
# Processing Record 3 of Set 10 | sao jose da coroa grande
# Processing Record 4 of Set 10 | lushunkou
# City not found. Skipping...
# Processing Record 5 of Set 10 | tual
# Processing Record 6 of Set 10 | taldan
# Processing Record 7 of Set 10 | vidim
# Processing Record 8 of Set 10 | shu
# Processing Record 9 of Set 10 | provideniya
# Processing Record 10 of Set 10 | naze
# Processing Record 11 of Set 10 | candelaria
# Processing Record 12 of Set 10 | honiara
# Processing Record 13 of Set 10 | sainte-rose
# Processing Record 14 of Set 10 | ocara
# Processing Record 15 of Set 10 | mogadishu
# Processing Record 16 of Set 10 | manyana
# Processing Record 17 of Set 10 | saint-francois
# Processing Record 18 of Set 10 | ancud
# Processing Record 19 of Set 10 | pingliang
# Processing Record 20 of Set 10 | longonjo
# Processing Record 21 of Set 10 | paraiso
# Processing Record 22 of Set 10 | kushima
# Processing Record 23 of Set 10 | sabibah
# City not found. Skipping...
# Processing Record 24 of Set 10 | ekhabi
# Processing Record 25 of Set 10 | nobeoka
# Processing Record 26 of Set 10 | hualmay
# Processing Record 27 of Set 10 | plavsk
# Processing Record 28 of Set 10 | burica
# City not found. Skipping...
# Processing Record 29 of Set 10 | umea
# Processing Record 30 of Set 10 | oyama
# Processing Record 31 of Set 10 | huari
# Processing Record 32 of Set 10 | golden
# Processing Record 33 of Set 10 | voyvozh
# Processing Record 34 of Set 10 | lazurne
# Processing Record 35 of Set 10 | brigantine
# Processing Record 36 of Set 10 | gustavo diaz ordaz
# Processing Record 37 of Set 10 | zapolyarnyy
# Processing Record 38 of Set 10 | vostok
# Processing Record 39 of Set 10 | fare
# Processing Record 40 of Set 10 | tumpat
# Processing Record 41 of Set 10 | lasa
# Processing Record 42 of Set 10 | villa carlos paz
# Processing Record 43 of Set 10 | clyde river
# Processing Record 44 of Set 10 | galich
# Processing Record 45 of Set 10 | unai
# Processing Record 46 of Set 10 | vernon
# Processing Record 47 of Set 10 | preobrazheniye
# Processing Record 48 of Set 10 | rolim de moura
# City not found. Skipping...
# Processing Record 49 of Set 10 | sambava
# Processing Record 50 of Set 10 | chara
# Processing Record 1 of Set 11 | kachug
# Processing Record 2 of Set 11 | lolua
# City not found. Skipping...
# Processing Record 3 of Set 11 | maragogi
# Processing Record 4 of Set 11 | moose factory
# Processing Record 5 of Set 11 | novopavlovka
# Processing Record 6 of Set 11 | pareora
# Processing Record 7 of Set 11 | port blair
# Processing Record 8 of Set 11 | riyadh
# Processing Record 9 of Set 11 | kattivakkam
# Processing Record 10 of Set 11 | inza
# Processing Record 11 of Set 11 | meulaboh
# Processing Record 12 of Set 11 | baghdad
# Processing Record 13 of Set 11 | harper
# Processing Record 14 of Set 11 | roald
# Processing Record 15 of Set 11 | avera
# Processing Record 16 of Set 11 | horodnytsya
# Processing Record 17 of Set 11 | sakakah
# Processing Record 18 of Set 11 | svetlaya
# Processing Record 19 of Set 11 | namatanai
# Processing Record 20 of Set 11 | oriximina
# Processing Record 21 of Set 11 | pozo colorado
# Processing Record 22 of Set 11 | biak
# Processing Record 23 of Set 11 | bokspits
# City not found. Skipping...
# Processing Record 24 of Set 11 | richards bay
# Processing Record 25 of Set 11 | cantaura
# Processing Record 26 of Set 11 | bombay
# Processing Record 27 of Set 11 | meyungs
# City not found. Skipping...
# Processing Record 28 of Set 11 | ahipara
# Processing Record 29 of Set 11 | eregli
# Processing Record 30 of Set 11 | uetendorf
# Processing Record 31 of Set 11 | husavik
# Processing Record 32 of Set 11 | asilah
# Processing Record 33 of Set 11 | aqtobe
# Processing Record 34 of Set 11 | cornwall
# Processing Record 35 of Set 11 | marsabit
# Processing Record 36 of Set 11 | sabinas hidalgo
# Processing Record 37 of Set 11 | sorong
# Processing Record 38 of Set 11 | palu
# Processing Record 39 of Set 11 | kununurra
# Processing Record 40 of Set 11 | duma
# Processing Record 41 of Set 11 | comodoro rivadavia
# Processing Record 42 of Set 11 | kloulklubed
# Processing Record 43 of Set 11 | galeana
# Processing Record 44 of Set 11 | villafranca de los barros
# Processing Record 45 of Set 11 | ullal
# Processing Record 46 of Set 11 | valparaiso
# Processing Record 47 of Set 11 | manthani
# Processing Record 48 of Set 11 | qaqortoq
# Processing Record 49 of Set 11 | thabazimbi
# Processing Record 50 of Set 11 | dilla
# Processing Record 1 of Set 12 | cidreira
# Processing Record 2 of Set 12 | challapata
# Processing Record 3 of Set 12 | bandarbeyla
# Processing Record 4 of Set 12 | gazanjyk
# Processing Record 5 of Set 12 | kainan
# Processing Record 6 of Set 12 | hwange
# Processing Record 7 of Set 12 | coihaique
# Processing Record 8 of Set 12 | abaza
# Processing Record 9 of Set 12 | petropavlovsk-kamchatskiy
# Processing Record 10 of Set 12 | yicheng
# Processing Record 11 of Set 12 | ola
# Processing Record 12 of Set 12 | mocambique
# City not found. Skipping...
# Processing Record 13 of Set 12 | arman
# Processing Record 14 of Set 12 | gallup
# Processing Record 15 of Set 12 | los llanos de aridane
# Processing Record 16 of Set 12 | cacak
# Processing Record 17 of Set 12 | mabaruma
# Processing Record 18 of Set 12 | manokwari
# Processing Record 19 of Set 12 | pavlogradka
# Processing Record 20 of Set 12 | copiapo
# Processing Record 21 of Set 12 | laureles
# Processing Record 22 of Set 12 | piacabucu
# Processing Record 23 of Set 12 | babu
# Processing Record 24 of Set 12 | inderborskiy
# City not found. Skipping...
# Processing Record 25 of Set 12 | nanakuli
# Processing Record 26 of Set 12 | narsaq
# Processing Record 27 of Set 12 | sola
# Processing Record 28 of Set 12 | mehran
# Processing Record 29 of Set 12 | jiblah
# Processing Record 30 of Set 12 | playa del carmen
# Processing Record 31 of Set 12 | el paso
# Processing Record 32 of Set 12 | cortez
# Processing Record 33 of Set 12 | tall kayf
# Processing Record 34 of Set 12 | panzhihua
# Processing Record 35 of Set 12 | karratha
# Processing Record 36 of Set 12 | maloshuyka
# City not found. Skipping...
# Processing Record 37 of Set 12 | eyl
# Processing Record 38 of Set 12 | lagunas
# Processing Record 39 of Set 12 | timaru
# Processing Record 40 of Set 12 | takoradi
# Processing Record 41 of Set 12 | flores
# Processing Record 42 of Set 12 | lashio
# Processing Record 43 of Set 12 | vestmannaeyjar
# Processing Record 44 of Set 12 | kalga
# Processing Record 45 of Set 12 | cuajinicuilapa
# Processing Record 46 of Set 12 | sardinata
# Processing Record 47 of Set 12 | samalaeulu
# City not found. Skipping...
# Processing Record 48 of Set 12 | kudahuvadhoo
# Processing Record 49 of Set 12 | morondava
# Processing Record 50 of Set 12 | monchegorsk
# Processing Record 1 of Set 13 | umm lajj
# Processing Record 2 of Set 13 | nelson bay
# Processing Record 3 of Set 13 | tukrah
# Processing Record 4 of Set 13 | solnechnyy
# Processing Record 5 of Set 13 | zhigansk
# Processing Record 6 of Set 13 | maniitsoq
# Processing Record 7 of Set 13 | samana
# Processing Record 8 of Set 13 | santa cruz
# Processing Record 9 of Set 13 | leshukonskoye
# Processing Record 10 of Set 13 | mitchell
# Processing Record 11 of Set 13 | plettenberg bay
# Processing Record 12 of Set 13 | quelimane
# Processing Record 13 of Set 13 | rtishchevo
# Processing Record 14 of Set 13 | west pensacola
# Processing Record 15 of Set 13 | belgaum
# Processing Record 16 of Set 13 | lar gerd
# City not found. Skipping...
# Processing Record 17 of Set 13 | chiredzi
# Processing Record 18 of Set 13 | georgetown
# Processing Record 19 of Set 13 | loubomo
# Processing Record 20 of Set 13 | pimentel
# Processing Record 21 of Set 13 | geraldton
# Processing Record 22 of Set 13 | elizabeth city
# Processing Record 23 of Set 13 | verkhoyansk
# Processing Record 24 of Set 13 | pemangkat
# Processing Record 25 of Set 13 | isla mujeres
# Processing Record 26 of Set 13 | awjilah
# Processing Record 27 of Set 13 | innisfail
# Processing Record 28 of Set 13 | banmo
# City not found. Skipping...
# Processing Record 29 of Set 13 | brewster
# Processing Record 30 of Set 13 | okha
# Processing Record 31 of Set 13 | kenitra
# Processing Record 32 of Set 13 | floro
# Processing Record 33 of Set 13 | ahumada
# City not found. Skipping...
# Processing Record 34 of Set 13 | birin
# Processing Record 35 of Set 13 | bahia blanca
# Processing Record 36 of Set 13 | kruisfontein
# Processing Record 37 of Set 13 | angoche
# Processing Record 38 of Set 13 | mirnyy
# Processing Record 39 of Set 13 | gerash
# Processing Record 40 of Set 13 | discovery bay
# Processing Record 41 of Set 13 | kumba
# Processing Record 42 of Set 13 | tessalit
# Processing Record 43 of Set 13 | lakhimpur
# Processing Record 44 of Set 13 | willowmore
# Processing Record 45 of Set 13 | ranong
# Processing Record 46 of Set 13 | gleisdorf
# Processing Record 47 of Set 13 | acarau
# Processing Record 48 of Set 13 | phun phin
# City not found. Skipping...
# Processing Record 49 of Set 13 | wellington
# Processing Record 50 of Set 13 | anori
# Processing Record 1 of Set 14 | bonfim
# Processing Record 2 of Set 14 | umm kaddadah
# Processing Record 3 of Set 14 | san pedro
# Processing Record 4 of Set 14 | korla
# Processing Record 5 of Set 14 | port ellen
# City not found. Skipping...
# Processing Record 6 of Set 14 | ogbomosho
# Processing Record 7 of Set 14 | ichikawa
# Processing Record 8 of Set 14 | green river
# Processing Record 9 of Set 14 | sal rei
# Processing Record 10 of Set 14 | lubao
# Processing Record 11 of Set 14 | kyshtovka
# Processing Record 12 of Set 14 | patacamaya
# Processing Record 13 of Set 14 | san luis
# Processing Record 14 of Set 14 | sergeyevka
# Processing Record 15 of Set 14 | mayo
# Processing Record 16 of Set 14 | greensburg
# Processing Record 17 of Set 14 | monroe
# Processing Record 18 of Set 14 | skjervoy
# Processing Record 19 of Set 14 | ewa beach
# Processing Record 20 of Set 14 | klaksvik
# Processing Record 21 of Set 14 | gillette
# Processing Record 22 of Set 14 | amasia
# Processing Record 23 of Set 14 | maltahohe
# Processing Record 24 of Set 14 | macusani
# Processing Record 25 of Set 14 | saint-georges
# Processing Record 26 of Set 14 | yazman
# Processing Record 27 of Set 14 | wollongong
# Processing Record 28 of Set 14 | carndonagh
# Processing Record 29 of Set 14 | sur
# Processing Record 30 of Set 14 | salym
# Processing Record 31 of Set 14 | cay
# Processing Record 32 of Set 14 | aykhal
# Processing Record 33 of Set 14 | ruteng
# Processing Record 34 of Set 14 | san felipe
# Processing Record 35 of Set 14 | phan thiet
# Processing Record 36 of Set 14 | el angel
# Processing Record 37 of Set 14 | wanning
# Processing Record 38 of Set 14 | manama
# Processing Record 39 of Set 14 | mudgee
# Processing Record 40 of Set 14 | springdale
# Processing Record 41 of Set 14 | skotina
# Processing Record 42 of Set 14 | loandjili
# Processing Record 43 of Set 14 | henties bay
# Processing Record 44 of Set 14 | prachuap khiri khan
# Processing Record 45 of Set 14 | chernyshevskiy
# Processing Record 46 of Set 14 | arrecife
# Processing Record 47 of Set 14 | saint anthony
# Processing Record 48 of Set 14 | balkanabat
# Processing Record 49 of Set 14 | saint-pierre
# Processing Record 50 of Set 14 | haverhill
# Processing Record 1 of Set 15 | carutapera
# Processing Record 2 of Set 15 | elko
# Processing Record 3 of Set 15 | kommunar
# Processing Record 4 of Set 15 | yongan
# Processing Record 5 of Set 15 | concordia
# Processing Record 6 of Set 15 | manggar
# Processing Record 7 of Set 15 | bilma
# Processing Record 8 of Set 15 | tamworth
# Processing Record 9 of Set 15 | zhireken
# Processing Record 10 of Set 15 | tommot
# Processing Record 11 of Set 15 | grimari
# City not found. Skipping...
# Processing Record 12 of Set 15 | kant
# Processing Record 13 of Set 15 | mansa
# Processing Record 14 of Set 15 | mahadday weyne
# City not found. Skipping...
# Processing Record 15 of Set 15 | broken hill
# Processing Record 16 of Set 15 | nantucket
# Processing Record 17 of Set 15 | bolu
# Processing Record 18 of Set 15 | pamekasan
# Processing Record 19 of Set 15 | dalinghe
# City not found. Skipping...
# Processing Record 20 of Set 15 | kinshasa
# Processing Record 21 of Set 15 | le port
# Processing Record 22 of Set 15 | haimen
# Processing Record 23 of Set 15 | trairi
# Processing Record 24 of Set 15 | bealanana
# Processing Record 25 of Set 15 | muyezerskiy
# Processing Record 26 of Set 15 | batagay-alyta
# Processing Record 27 of Set 15 | pulandian
# Processing Record 28 of Set 15 | tevaitoa
# Processing Record 29 of Set 15 | alikalia
# Processing Record 30 of Set 15 | ust-nera
# Processing Record 31 of Set 15 | anchorage
# Processing Record 32 of Set 15 | prince rupert
# Processing Record 33 of Set 15 | harer
# Processing Record 34 of Set 15 | tibiri
# Processing Record 35 of Set 15 | state college
# Processing Record 36 of Set 15 | yinchuan
# Processing Record 37 of Set 15 | angra
# City not found. Skipping...
# Processing Record 38 of Set 15 | barbar
# City not found. Skipping...
# Processing Record 39 of Set 15 | pampa
# Processing Record 40 of Set 15 | kirkenaer
# Processing Record 41 of Set 15 | bayir
# Processing Record 42 of Set 15 | naryan-mar
# Processing Record 43 of Set 15 | dipkarpaz
# City not found. Skipping...
# Processing Record 44 of Set 15 | pasighat
# Processing Record 45 of Set 15 | beawar
# Processing Record 46 of Set 15 | sao felix do xingu
# Processing Record 47 of Set 15 | san matias
# Processing Record 48 of Set 15 | simdega
# Processing Record 49 of Set 15 | gangotri
# City not found. Skipping...
# Processing Record 50 of Set 15 | izhma
# Processing Record 1 of Set 16 | ojinaga
# Processing Record 2 of Set 16 | longyearbyen
# Processing Record 3 of Set 16 | san quintin
# Processing Record 4 of Set 16 | roswell
# Processing Record 5 of Set 16 | tres lagoas
# Processing Record 6 of Set 16 | fallon
# Processing Record 7 of Set 16 | surt
# Processing Record 8 of Set 16 | maraba
# Processing Record 9 of Set 16 | ushtobe
# Processing Record 10 of Set 16 | yar-sale
# Processing Record 11 of Set 16 | sa kaeo
# Processing Record 12 of Set 16 | marsh harbour
# Processing Record 13 of Set 16 | havre-saint-pierre
# Processing Record 14 of Set 16 | babati
# Processing Record 15 of Set 16 | tiznit
# Processing Record 16 of Set 16 | ust-kuyga
# Processing Record 17 of Set 16 | viedma
# Processing Record 18 of Set 16 | kulhudhuffushi
# Processing Record 19 of Set 16 | douglas
# Processing Record 20 of Set 16 | huarmey
# Processing Record 21 of Set 16 | wukari
# Processing Record 22 of Set 16 | sompeta
# Processing Record 23 of Set 16 | severo-yeniseyskiy
# Processing Record 24 of Set 16 | sechura
# Processing Record 25 of Set 16 | itabuna
# Processing Record 26 of Set 16 | kang
# Processing Record 27 of Set 16 | kuandian
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
len(city_data)
# Out:
# 712

# %%
# Add the data to a new DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df
# Out:
#                    City Country      Lat       Lng  Max Temp  Humidity  \
# 0                Dikson      RU  73.5069   80.5464     30.34        79
# 1              Bengkulu      ID  -3.8004  102.2655     81.54        72
# 2            Bredasdorp      ZA -34.5322   20.0403     51.03        63
# 3              La Ronge      CA  55.1001 -105.2842     48.45        29
# 4               Paamiut      GL  61.9940  -49.6678     33.80        86
# ..                  ...     ...      ...       ...       ...       ...
# 707  Severo-Yeniseyskiy      RU  60.3725   93.0408     49.26        95
# 708             Sechura      PE  -5.5569  -80.8222     67.77        77
# 709             Itabuna      BR -14.7856  -39.2803     64.17        73
# 710                Kang      BW -23.6752   22.7876     57.63        49
# 711            Kuandian      CN  40.7286  124.7847     69.22        54
#
#      Cloudiness  Wind Speed Current Description
# 0           100        9.35     overcast clouds
# 1            62        0.94       broken clouds
# 2            29        6.24    scattered clouds
# 3            40       14.97    scattered clouds
# 4            78        3.53       broken clouds
# ..          ...         ...                 ...
# 707         100        5.30       moderate rain
# 708          30       13.87    scattered clouds
# 709         100        1.95     overcast clouds
# 710           6       12.12           clear sky
# 711           0        6.15           clear sky
#
# [712 rows x 9 columns]

# %%
# Export the DataFrame as a CSV file, and save it as WeatherPy_Database.csv in the Weather_Database folder
# Create the output file (CSV).
output_data_file = "Weather_Database/WeatherPy_Database.csv"

# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
